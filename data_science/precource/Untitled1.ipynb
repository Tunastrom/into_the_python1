# %%
class Notebook():
    def __init__(self, title):
        self.title = title
        self.page_number = 1
        self.notes = {}
        
    def add_note(self, note, page = 0):     
        if self.page_number <= 300:
            if page == 0: 
                self.notes[self.page_number] = note
                self.page_number += 1
            else:
                self.notes[page] = note
                self.page_number += 1
        else:
            print('300Page가 모두 채워졌습니다.')
    
    def remove_note(self, page_number):
        if page_number in self.notes.keys():
            self.page_number -= 1
            return self.notes.pop(page_number)  
        else:
            print('존재하지 않는 Page입니다.')
            
    def get_number_of_pages(self):
        return len(self.notes.keys())

# %%
class Note():
    def __init__(self, content = None):
        self.contents = content
        
    def write_contents(self, content):
        self.contents = content
        
    def remove_all(self):
        self.contents = ''
        
    def __add__(self, other):
        return self.contents + other.contents
    
    def __str__(self):
        return self.contents

# %%
note1 = Note()
note1.write_contents('무한도전')
print(note1)
note1.remove_all()
print(note1)
# Out:
# 무한도전

# %%
note1 + note2
# Out:
# '무한도전'

# %%
jaesuk_diary = Notebook('재석일기')
jaesuk_diary.title
# Out:
# '재석일기'

# %%
note = Note('무한도전')
for i in range(1,400):
    if i > 1:
        jaesuk_diary.add_note(note,i)
    else:
        jaesuk_diary.add_note(note)
jaesuk_diary.get_number_of_pages()
# Out:
# 300Page가 모두 채워졌습니다.
# 300Page가 모두 채워졌습니다.
# 300Page가 모두 채워졌습니다.
# 300Page가 모두 채워졌습니다.
# 300Page가 모두 채워졌습니다.
# 300Page가 모두 채워졌습니다.
# 300Page가 모두 채워졌습니다.
# 300Page가 모두 채워졌습니다.
# 300Page가 모두 채워졌습니다.
# 300Page가 모두 채워졌습니다.
# 300Page가 모두 채워졌습니다.
# 300Page가 모두 채워졌습니다.
# 300Page가 모두 채워졌습니다.
# 300Page가 모두 채워졌습니다.
# 300Page가 모두 채워졌습니다.
# 300Page가 모두 채워졌습니다.
# 300Page가 모두 채워졌습니다.
# 300Page가 모두 채워졌습니다.
# 300Page가 모두 채워졌습니다.
# 300Page가 모두 채워졌습니다.
# 300Page가 모두 채워졌습니다.
# 300Page가 모두 채워졌습니다.
# 300Page가 모두 채워졌습니다.
# 300Page가 모두 채워졌습니다.
# 300Page가 모두 채워졌습니다.
# 300Page가 모두 채워졌습니다.
# 300Page가 모두 채워졌습니다.
# 300Page가 모두 채워졌습니다.
# 300Page가 모두 채워졌습니다.
# 300Page가 모두 채워졌습니다.
# 300Page가 모두 채워졌습니다.
# 300Page가 모두 채워졌습니다.
# 300Page가 모두 채워졌습니다.
# 300Page가 모두 채워졌습니다.
# 300Page가 모두 채워졌습니다.
# 300Page가 모두 채워졌습니다.
# 300Page가 모두 채워졌습니다.
# 300Page가 모두 채워졌습니다.
# 300Page가 모두 채워졌습니다.
# 300Page가 모두 채워졌습니다.
# 300Page가 모두 채워졌습니다.
# 300Page가 모두 채워졌습니다.
# 300Page가 모두 채워졌습니다.
# 300Page가 모두 채워졌습니다.
# 300Page가 모두 채워졌습니다.
# ...

# %%
jaesuk_diary.notes
# Out:
# {1: <__main__.Note at 0x195c05327f0>,
#  2: <__main__.Note at 0x195c05327f0>,
#  3: <__main__.Note at 0x195c05327f0>,
#  4: <__main__.Note at 0x195c05327f0>,
#  5: <__main__.Note at 0x195c05327f0>,
#  6: <__main__.Note at 0x195c05327f0>,
#  7: <__main__.Note at 0x195c05327f0>,
#  8: <__main__.Note at 0x195c05327f0>,
#  9: <__main__.Note at 0x195c05327f0>,
#  10: <__main__.Note at 0x195c05327f0>,
#  11: <__main__.Note at 0x195c05327f0>,
#  12: <__main__.Note at 0x195c05327f0>,
#  13: <__main__.Note at 0x195c05327f0>,
#  14: <__main__.Note at 0x195c05327f0>,
#  15: <__main__.Note at 0x195c05327f0>,
#  16: <__main__.Note at 0x195c05327f0>,
#  17: <__main__.Note at 0x195c05327f0>,
#  18: <__main__.Note at 0x195c05327f0>,
#  19: <__main__.Note at 0x195c05327f0>,
#  20: <__main__.Note at 0x195c05327f0>,
#  21: <__main__.Note at 0x195c05327f0>,
#  22: <__main__.Note at 0x195c05327f0>,
#  23: <__main__.Note at 0x195c05327f0>,
#  24: <__main__.Note at 0x195c05327f0>,
# ...

# %%
for i in range(1,301):
    jaesuk_diary.remove_note(i)
# Out:
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# 존재하지 않는 Page입니다.
# ...

# %%
jaesuk_diary.get_number_of_pages()
# Out:
# 0

# %%
jaesuk_diary.notes
# Out:
# {}
